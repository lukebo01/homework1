# %% [markdown]
# 1° NOTEBOOK PER L' HW1 di Ingegneria dei Dati.
#
# Membri del team:
# - Luca Borrelli
# - Rainer Cabral Ilao

# %%
import requests
from bs4 import BeautifulSoup
import os
from urllib.parse import urljoin
from xml.etree import ElementTree as ET

# %% [markdown]
# Inseriamo All'interno di una lista i link per le pages della search per i seguenti argomenti:
# - Facial Recognition

# %%
list = [
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=0',
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=50',
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=100',
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=150',
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=200',
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=250',
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=300',
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=350',
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=400',
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=450',
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=500',
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=550',
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=600',
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=650',
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=700',
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=750',
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=800',
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=850',
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=900',
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=950',
    'https://arxiv.org/search/advanced?advanced=&terms-0-operator=AND&terms-0-term=Speech+recognition&terms-0-field=all&classification-computer_science=y&classification-physics_archives=all&classification-include_cross_list=include&date-filter_by=all_dates&date-year=&date-from_date=&date-to_date=&date-date_type=submitted_date&abstracts=show&size=50&order=-announced_date_first&start=1000',
]

# Genero la cartella searchPages e dentro ci salvo la pagina scaricata
if not os.path.exists("searchPages"):
    os.makedirs("searchPages")

# Funzione per il donwload di una pagina mhtml nella cartella searchPages
def download_html(url):
  """Scarica il contenuto HTML di una pagina web.

  Args:
    url: L'URL della pagina web da scaricare.

  Returns:
    Il contenuto HTML della pagina web come stringa, o None se la richiesta fallisce.
  """

  try:
    risposta = requests.get(url)
    risposta.raise_for_status()  # Gestisce errori di rete
    return risposta.text  # Restituisce il contenuto HTML come stringa
  except requests.exceptions.RequestException as e:
    print(f"Errore durante il download della pagina: {e}")
    return None  # Restituisce None se la richiesta fallisce

#Se la cartella searchPages non esiste la creo
if not os.path.exists("searchPages"):
    os.makedirs("searchPages")

# Esempio di utilizzo
i=0
for url in list:
    html = download_html(url)
    #Sfrutto i per creare sstringhe col nome del file in modo da non sovrascrivere i file
    i=i+1
    namePages = "searchPages/page"+str(i)+".html"
    with open(namePages, "w", encoding="utf-8") as file:
        file.write(html)

# %% [markdown]
# Funzione in grado di procedere ad analizzare una pagina di una search del sito arxiv.org sfruttando xpath.
# La seguente funzione procede ad andare a cercare i link che portano all' anteprima di ogni paper presente, ottenendo così un nuovo link, questo link va modificato sostituendo la 'x' con il 5, in questo modo si viene reindirizzati al sito ausiliario ar5iv.labs.arxiv.org.
#
# Esempio:
# Se ci troviamo nella pagina: https://arxiv.org/abs/2407.16234
# riscrivendolo come https://ar5iv.org/abs/2407.16234 ed effettuando la sua request, si viene reindirizzati alla pagina html: https://ar5iv.labs.arxiv.org/html/2407.16234
#
# da qui si può procedere a scaricare il singolo paper in formato mhtml, la sua relativa conversione html avverrà successivamente.

# %%
def estrai_link_papers(html_content):
  """Estrae i link delle pagine HTML dei singoli papers da una pagina di ricerca di arXiv.org.

  Args:
    html_content: Il contenuto HTML della pagina di ricerca.

  Returns:
    Una lista di tuple contenenti l'URL modificato e il codice del documento.
  """

  soup = BeautifulSoup(html_content, 'html.parser')

  link_papers = []
  for link in soup.select("ol.breathe-horizontal li div p a[href*='abs']"): 
    paper_url = link['href']

    # Sostituisci "x" con "5" per ottenere l'URL di ar5iv
    ar5iv_url = paper_url.replace("x", "5")

    # Estrai il codice del documento
    codice_documento = paper_url.split('/')[-1]

    # Aggiungi il link modificato e il codice del documento alla lista
    link_papers.append((ar5iv_url, codice_documento))

  return link_papers

#Creo il file txt dove salverò i link se non esiste già
if not os.path.exists("links.txt"):
    open("links.txt", "w").close()
    
# Esempio di utilizzo
for page in os.listdir("searchPages"):
    with open("searchPages/" + page, "r", encoding="utf-8") as file:
        html_content = file.read()
    link_papers = estrai_link_papers(html_content)


    # Salva i link in un file di testo (in modalità "a" per appendere)
    with open("links.txt", "a", encoding="utf-8") as file:
        for ar5iv_url, codice_documento in link_papers:
            file.write(f"Link: {ar5iv_url}\n")
            file.write(f"Codice: {codice_documento}\n")

# %% [markdown]
# Ora procediamo a scaricare tutti i papers in html leggendo i links presenti in readme

# %%
def download_paper_html(link, codice):
  """Scarica la pagina HTML associata ad un link e la salva nella cartella 'sources'.

  Args:
    link: L'URL del paper.
    codice: Il codice del documento.
  """

  try:
    print(f"Scaricando pagina {codice}: {link}")
    response = requests.get(link)
    response.raise_for_status()  # Gestisci gli errori di richiesta HTTP
    
    # Crea la cartella 'sources' se non esiste
    os.makedirs("sources", exist_ok=True)

    # Salva la pagina HTML nel file con nome pari al codice
    with open(f"sources/{codice}.html", "w", encoding="utf-8") as file:
      file.write(response.text)

    print(f"Pagina {codice} scaricata correttamente.")

  except requests.exceptions.RequestException as e:
    print(f"Errore durante il download di {codice}: {e}")

# Esempio di utilizzo
with open("links.txt", "r", encoding="utf-8") as file:
  for line in file:
    if line.startswith("Link:"):
      link = line.strip().split(" ")[1]
    elif line.startswith("Codice:"):
      codice = line.strip().split(" ")[1]
      download_paper_html(link, codice)

print("Download Completed.")
# Out:
# Scaricando pagina 2410.07771: https://ar5iv.org/abs/2410.07771
# Pagina 2410.07771 scaricata correttamente.
# Scaricando pagina 2410.07757: https://ar5iv.org/abs/2410.07757
# Pagina 2410.07757 scaricata correttamente.
# Scaricando pagina 2410.07530: https://ar5iv.org/abs/2410.07530
# Pagina 2410.07530 scaricata correttamente.
# Scaricando pagina 2410.07400: https://ar5iv.org/abs/2410.07400
# Pagina 2410.07400 scaricata correttamente.
# Scaricando pagina 2410.07274: https://ar5iv.org/abs/2410.07274
# Pagina 2410.07274 scaricata correttamente.
# Scaricando pagina 2410.05997: https://ar5iv.org/abs/2410.05997
# Pagina 2410.05997 scaricata correttamente.
# Scaricando pagina 2410.05986: https://ar5iv.org/abs/2410.05986
# Pagina 2410.05986 scaricata correttamente.
# Scaricando pagina 2410.05586: https://ar5iv.org/abs/2410.05586
# Pagina 2410.05586 scaricata correttamente.
# Scaricando pagina 2410.05423: https://ar5iv.org/abs/2410.05423
# Pagina 2410.05423 scaricata correttamente.
# ...

# %% [markdown]
# Script che controlla se un link è disponibile in ar5iv

# %%
html_pages = os.listdir("sources")

for page in html_pages:
    with open("sources/" + page, "r", encoding="utf-8") as file:
        html_content = file.read()

    soup = BeautifulSoup(html_content, 'html.parser')

    if soup.find("a",class_="is-sr-only") != None:
        os.remove(f"sources/{page}")

# %%
html_pages = os.listdir("sources")
html_pages.sort()

with open("README.md", "w", encoding="utf-8") as readme:
    for page in html_pages:
        with open("sources/" + page, "r", encoding="utf-8") as file:
            html_content = file.read()

        soup = BeautifulSoup(html_content, 'html.parser')

        meta_tag = soup.find('meta', property='og:url')
        content_value = meta_tag["content"]
        print(content_value)

        readme.write(f"{content_value}\n")
# Out:
# https://ar5iv.labs.arxiv.org/html/2402.13004
# https://ar5iv.labs.arxiv.org/html/2402.13152
# https://ar5iv.labs.arxiv.org/html/2402.13208
# https://ar5iv.labs.arxiv.org/html/2402.13432
# https://ar5iv.labs.arxiv.org/html/2402.14185
# https://ar5iv.labs.arxiv.org/html/2402.15151
# https://ar5iv.labs.arxiv.org/html/2402.16124
# https://ar5iv.labs.arxiv.org/html/2402.17184
# https://ar5iv.labs.arxiv.org/html/2402.17249
# https://ar5iv.labs.arxiv.org/html/2402.17496
# https://ar5iv.labs.arxiv.org/html/2402.17723
# https://ar5iv.labs.arxiv.org/html/2402.17775
# https://ar5iv.labs.arxiv.org/html/2402.18007
# https://ar5iv.labs.arxiv.org/html/2402.18302
# https://ar5iv.labs.arxiv.org/html/2402.18923
# https://ar5iv.labs.arxiv.org/html/2403.00212
# https://ar5iv.labs.arxiv.org/html/2403.00274
# https://ar5iv.labs.arxiv.org/html/2403.01087
# https://ar5iv.labs.arxiv.org/html/2403.01255
# https://ar5iv.labs.arxiv.org/html/2403.01309
# https://ar5iv.labs.arxiv.org/html/2403.01901
# ...
