# %% [markdown]
# Notebook dedicato all'estrazione di queste informazioni:
# - tables
# - tables caption
# - footnotes in the tables or in the captions
# - paragraphs containing references to the extracted tables

# %%
from lxml import html
import os
import json
import re

# %%
# query xpath che serviranno per estrarre le informazioni
querys = {
    "figures": "//figure[contains(@class,'ltx_table')]",
    "caption": ".//figcaption//text()",
    "html_table": "./div | ./table | ./p",
    "table_id": "./@id",
    "footnotes": ".//figcaption[contains(text(), 'Note')]/text()",
    "footnotes_bli": ".//cite//a/text() | .//cite//span/text()",
    "paragraphs": "//div[contains(@class, 'ltx_para')]//p | //div[contains(@class, 'ltx_para ltx_noindent')]//p"
}

# %%
# Funzione per sostituire caratteri speciali
def pulisci_stringa(s:str):
    s = s.replace('\u00a0', ' ')  # Sostituisce lo spazio non interrompibile con spazio normale
    s = s.replace('\u201c', '"')  # Sostituisce virgolette di apertura con virgolette standard
    s = s.replace('\u201d', '"')  # Sostituisce virgolette di chiusura con virgolette standard
    s = s.replace('\u00fc', 'ü')  # Sostituisce ü con u con umlaut
    s = s.replace('\u00e9', 'é')  # Sostituisce é con e accentata
    s = s.replace('\u00e8', 'è')  # Sostituisce è con e accentata
    s = s.replace('\u00e0', 'à')  # Sostituisce à con a accentata
    s = s.replace('\u00f3', 'ó')  # Sostituisce ó con o accentata
    s = s.replace('\u00f4', 'ô')  # Sostituisce ô con o circonflesso
    s = s.replace('\u00e2', 'â')  # Sostituisce â con a circonflesso
    s = s.replace('\u00ea', 'ê')  # Sostituisce ê con e circonflesso
    s = s.replace('\u00ee', 'î')  # Sostituisce î con i circonflesso
    s = s.replace('\u00fb', 'û')  # Sostituisce û con u circonflesso
    s = s.replace('\u00e7', 'ç')  # Sostituisce ç con c cediglia
    s = s.replace('\u00f9', 'ù')  # Sostituisce ù con u accentata
    s = s.replace('\u00f1', 'ñ')  # Sostituisce ñ con n tilde
    s = s.replace('\u00f6', 'ö')  # Sostituisce ö con o umlaut
    s = s.replace('\u00e4', 'ä')  # Sostituisce ä con a umlaut
    s = s.replace('\u00eb', 'ë')  # Sostituisce ë con e umlaut
    s = s.replace('\u00ef', 'ï')  # Sostituisce ï con i umlaut
    s = s.replace('\u00fc', 'ü')  # Sostituisce ü con u umlaut
    s = s.replace('\u00ff', 'ÿ')  # Sostituisce ÿ con y umlaut
    s = s.replace('\u00e5', 'å')  # Sostituisce å con a ring
    s = s.replace('\u00f8', 'ø')  # Sostituisce ø con o barrata
    s = s.replace('\u00e6', 'æ')  # Sostituisce æ con ae legato
    s = s.replace('\u00f6', 'ö')  # Sostituisce ö con o umlaut
    s = s.replace('\u00e4', 'ä')  # Sostituisce ä con a umlaut
    s = s.replace('\u00eb', 'ë')  # Sostituisce ë con e umlaut
    s = s.replace('\u00ef', 'ï')  # Sostituisce ï con i umlaut
    s = s.replace('\u00fc', 'ü')  # Sostituisce ü con u umlaut
    s = s.replace('\u00ff', 'ÿ')  # Sostituisce ÿ con y umlaut
    s = s.replace('\u00fc', 'ü')  # Sostituisce ü con u umlaut
    s = s.replace('\u00a0', ' ')  
    return s

# Funzione per estrarre il numero dalla stringa, sia arabo che romano
def extract_table_number(escaped_caption):
    # Prova prima con un numero arabo
    arabic_number = re.search(r'\d+', escaped_caption)
    if arabic_number:
        return arabic_number.group()  # Restituisce il numero arabo come stringa
    
    # Se non c'è numero arabo, prova con numero romano
    roman_number = re.search(r'\b[I|V|X|L|C|D|M]+\b', escaped_caption)
    if roman_number:
        return roman_number.group()

    return None  # Nessun numero trovato

# %%
def get_footnotesBlib(tree:html.HtmlElement, figure: html.HtmlElement):
    cite_numbers = figure.xpath(querys["footnotes_bli"])
    footnotes = set()

    for cite in cite_numbers:
        cite_number = cite.strip('[]')

        footnote = tree.xpath(f'//li[@id="bib.bib{cite_number}"]/span[@class="ltx_bibblock"]//text()')
        if footnote:
            full_text = " ".join(footnote).strip()
            full_text = pulisci_stringa(full_text)
            footnotes.add(full_text)
            
    footnotes = list(footnotes)
    return footnotes

def get_footnotes(tree:html.HtmlElement, figure: html.HtmlElement):
    footnotes = figure.xpath(querys["footnotes"])
    
    return footnotes

def get_references(tree: html.HtmlElement, caption):
    references = []
    escaped_caption = json.dumps(caption.split(":")[0])
    number = extract_table_number(escaped_caption)
    xpath_query = (
        f'//div[contains(@class, "ltx_para")]//p[a[contains(@title, {escaped_caption})]] | '
        f'//div[contains(@class, "ltx_para")]//p[a[span[text()="{number}"]]] | '
        f'//div[contains(@class, "ltx_para")]//p[span[text()="{number}"]] | '
        f'//div[contains(@class, "ltx_para")]//p[contains(text(), "{number}")] | '
        f'//div[contains(@class, "ltx_para")]//p[span[@class="ltx_text ltx_ref_tag" and text()="{number}"]] | '
        f'//div[contains(@class, "ltx_para")]//p[span[contains(text(), "{number}")]] |'
        f'//div[contains(@class, "ltx_para ltx_noindent")]//p[a[contains(@title, {escaped_caption})]] | '
        f'//div[contains(@class, "ltx_para ltx_noindent")]//p[a[span[text()="{number}"]]] | '
        f'//div[contains(@class, "ltx_para ltx_noindent")]//p[span[text()="{number}"]] | '
        f'//div[contains(@class, "ltx_para ltx_noindent")]//p[contains(text(), "{number}")] | '
        f'//div[contains(@class, "ltx_para ltx_noindent")]//p[span[@class="ltx_text ltx_ref_tag" and text()="{number}"]] | '
        f'//div[contains(@class, "ltx_para ltx_noindent")]//p[span[contains(text(), "{number}")]]'
    )
    try:
        relevant_paragraphs = tree.xpath(xpath_query)
        
    except Exception as e:
        print(f"Errore nel calcolo dell'XPath: {e}")
        relevant_paragraphs = []
    
    for paragraph in relevant_paragraphs:
        references.append(html.tostring(paragraph, encoding="utf-8").decode("utf-8"))
        
    #Procedo a trasformare i pezzi di codice html di references in stringhe con solo il contenuto testuale
    for i in range(len(references)):
        references[i] = re.sub(r'<.*?>', '', references[i])
    
    #pulisco le references
    references = [pulisci_stringa(reference) for reference in references]

    # Trasforma i pezzi di codice HTML in stringhe con solo il contenuto testuale
    filtered_references = []
    for reference in references:
        # Rimuovi i tag HTML
        text = re.sub(r'<.*?>', '', reference).strip()
        # Controlla se contiene "Table" e il numero specificato
        if f"Table {number} " in text:
            filtered_references.append(text)
            
        if f"Table {number}," in text:
            filtered_references.append(text)
        
        if f"Table {number}." in text:
            filtered_references.append(text)
        
        if f"Table {number}:" in text:
            filtered_references.append(text)
        
        if f"Table {number})" in text:
            filtered_references.append(text)
        
        if f"Table {number}(" in text:
            filtered_references.append(text)
        
        if f"Table {number}]" in text:
            filtered_references.append(text)
        
        if f"Table {number}[" in text:
            filtered_references.append(text)
        
        if f"table {number} " in text:
            filtered_references.append(text)
        
        if f"table {number}," in text:
            filtered_references.append(text)
        
        if f"table {number}." in text:
            filtered_references.append(text)
        
        if f"table {number}:" in text:
            filtered_references.append(text)
        
        if f"table {number})" in text:
            filtered_references.append(text)
        
        if f"table {number}(" in text:
            filtered_references.append(text)
        
        if f"table {number}]" in text:
            filtered_references.append(text)
        
        if f"table {number}[" in text:
            filtered_references.append(text)

    return filtered_references

# %%
# Funzione per estrarre le informazioni da un file HTML
def extract_info_from_html(paper_path):
    result = {}

    with open(paper_path, "r", encoding="utf-8") as paper:
        content = paper.read()

    tree: html.HtmlElement = html.fromstring(content)
    figures: list[html.HtmlElement] = tree.xpath(querys["figures"])
    
    for index, figure in enumerate(figures):
        # estrazione table id
        table_id = figure.xpath(querys["table_id"])[0]

        # estrazione html_table
        html_table = figure.xpath(querys["html_table"])

        '''
        if len(html_table) == 0:
            print(index,paper_path)
        '''
        
        # estrazione caption
        caption = figure.xpath(querys["caption"])
        if type(caption) == list:
            caption = " ".join(caption)
        
        # Crea l'oggetto risultato per la tabella
        result[table_id] = {
            "caption": caption,
            "table": html.tostring(figure, encoding="utf-8").decode("utf-8"),
            "footnotes": get_footnotes(tree, figure),  # Aggiungi i piè di pagina trovati
            "references": get_references(tree, caption)
        }

    return result

# %%
papers = os.listdir("sources")
papers.remove(".txt")
papers.sort()
#Se non esiste la cartella extraction, creo la cartella
if not os.path.exists("extraction"):
    os.makedirs("extraction")

i=1
for paper in papers:
        print(f"Paper elaborati:  {i}, actual paper: {paper}")
        i=i+1
    #if(paper == "2406.05784.html" or paper == "2403.07938.html"):
        print(f"Elaborazione del paper {paper}")
        result = extract_info_from_html(f"sources/{paper}")
        paper_name_split = paper.split(".")
        paper_name = f"{paper_name_split[0]}.{paper_name_split[1]}"
        
        with open(f"extraction/{paper_name}.json","w") as file:
            json.dump(result, file, indent=4)
# Out:
# Paper elaborati:  1, actual paper: 2402.13004.html
# Elaborazione del paper 2402.13004.html
# Paper elaborati:  2, actual paper: 2402.13152.html
# Elaborazione del paper 2402.13152.html
# Paper elaborati:  3, actual paper: 2402.13208.html
# Elaborazione del paper 2402.13208.html
# Paper elaborati:  4, actual paper: 2402.13432.html
# Elaborazione del paper 2402.13432.html
# Paper elaborati:  5, actual paper: 2402.14185.html
# Elaborazione del paper 2402.14185.html
# Paper elaborati:  6, actual paper: 2402.15151.html
# Elaborazione del paper 2402.15151.html
# Paper elaborati:  7, actual paper: 2402.16124.html
# Elaborazione del paper 2402.16124.html
# Paper elaborati:  8, actual paper: 2402.17184.html
# Elaborazione del paper 2402.17184.html
# Paper elaborati:  9, actual paper: 2402.17249.html
# Elaborazione del paper 2402.17249.html
# Paper elaborati:  10, actual paper: 2402.17496.html
# Elaborazione del paper 2402.17496.html
# Paper elaborati:  11, actual paper: 2402.17723.html
# Elaborazione del paper 2402.17723.html
# Paper elaborati:  12, actual paper: 2402.17775.html
# Elaborazione del paper 2402.17775.html
# Paper elaborati:  13, actual paper: 2402.18007.html
# Elaborazione del paper 2402.18007.html
# Paper elaborati:  14, actual paper: 2402.18302.html
# Elaborazione del paper 2402.18302.html
# Paper elaborati:  15, actual paper: 2402.18923.html
# Elaborazione del paper 2402.18923.html
# Paper elaborati:  16, actual paper: 2403.00212.html
# Elaborazione del paper 2403.00212.html
# Paper elaborati:  17, actual paper: 2403.00274.html
# Elaborazione del paper 2403.00274.html
# Paper elaborati:  18, actual paper: 2403.01087.html
# Elaborazione del paper 2403.01087.html
# Paper elaborati:  19, actual paper: 2403.01255.html
# Elaborazione del paper 2403.01255.html
# Paper elaborati:  20, actual paper: 2403.01309.html
# Elaborazione del paper 2403.01309.html
# Paper elaborati:  21, actual paper: 2403.01901.html
# Elaborazione del paper 2403.01901.html
# Paper elaborati:  22, actual paper: 2403.02010.html
# Elaborazione del paper 2403.02010.html
# Paper elaborati:  23, actual paper: 2403.02938.html
# Elaborazione del paper 2403.02938.html
# Paper elaborati:  24, actual paper: 2403.03095.html
# Elaborazione del paper 2403.03095.html
# Paper elaborati:  25, actual paper: 2403.03145.html
# Elaborazione del paper 2403.03145.html
# Paper elaborati:  26, actual paper: 2403.03461.html
# Elaborazione del paper 2403.03461.html
# Paper elaborati:  27, actual paper: 2403.03522.html
# Elaborazione del paper 2403.03522.html
# Paper elaborati:  28, actual paper: 2403.03538.html
# Elaborazione del paper 2403.03538.html
# Paper elaborati:  29, actual paper: 2403.03947.html
# Elaborazione del paper 2403.03947.html
# Paper elaborati:  30, actual paper: 2403.04245.html
# Elaborazione del paper 2403.04245.html
# Paper elaborati:  31, actual paper: 2403.04445.html
# Elaborazione del paper 2403.04445.html
# Paper elaborati:  32, actual paper: 2403.04661.html
# Elaborazione del paper 2403.04661.html
# Paper elaborati:  33, actual paper: 2403.04800.html
# Elaborazione del paper 2403.04800.html
# Paper elaborati:  34, actual paper: 2403.05916.html
# Elaborazione del paper 2403.05916.html
# Paper elaborati:  35, actual paper: 2403.07937.html
# Elaborazione del paper 2403.07937.html
# Paper elaborati:  36, actual paper: 2403.07938.html
# Elaborazione del paper 2403.07938.html
# Paper elaborati:  37, actual paper: 2403.08196.html
# Elaborazione del paper 2403.08196.html
# Paper elaborati:  38, actual paper: 2403.08492.html
# Elaborazione del paper 2403.08492.html
# Paper elaborati:  39, actual paper: 2403.09451.html
# Elaborazione del paper 2403.09451.html
# Paper elaborati:  40, actual paper: 2403.10488.html
# Elaborazione del paper 2403.10488.html
# Paper elaborati:  41, actual paper: 2403.10518.html
# Elaborazione del paper 2403.10518.html
# Paper elaborati:  42, actual paper: 2403.10565.html
# Elaborazione del paper 2403.10565.html
# Paper elaborati:  43, actual paper: 2403.10796.html
# Elaborazione del paper 2403.10796.html
# Paper elaborati:  44, actual paper: 2403.10805.html
# Elaborazione del paper 2403.10805.html
# Paper elaborati:  45, actual paper: 2403.10904.html
# Elaborazione del paper 2403.10904.html
# Paper elaborati:  46, actual paper: 2403.12273.html
# Elaborazione del paper 2403.12273.html
# Paper elaborati:  47, actual paper: 2403.12425.html
# Elaborazione del paper 2403.12425.html
# Paper elaborati:  48, actual paper: 2403.12821.html
# Elaborazione del paper 2403.12821.html
# Paper elaborati:  49, actual paper: 2403.14083.html
# Elaborazione del paper 2403.14083.html
# Paper elaborati:  50, actual paper: 2403.14174.html
# Elaborazione del paper 2403.14174.html
# Paper elaborati:  51, actual paper: 2403.14290.html
# Elaborazione del paper 2403.14290.html
# Paper elaborati:  52, actual paper: 2403.15377.html
# Elaborazione del paper 2403.15377.html
# Paper elaborati:  53, actual paper: 2403.15442.html
# Elaborazione del paper 2403.15442.html
# Paper elaborati:  54, actual paper: 2403.15469.html
# Elaborazione del paper 2403.15469.html
# Paper elaborati:  55, actual paper: 2403.15510.html
# Elaborazione del paper 2403.15510.html
# Paper elaborati:  56, actual paper: 2403.17363.html
# Elaborazione del paper 2403.17363.html
# Paper elaborati:  57, actual paper: 2403.17385.html
# Elaborazione del paper 2403.17385.html
# Paper elaborati:  58, actual paper: 2403.17562.html
# Elaborazione del paper 2403.17562.html
# Paper elaborati:  59, actual paper: 2403.18635.html
# Elaborazione del paper 2403.18635.html
# Paper elaborati:  60, actual paper: 2403.18721.html
# Elaborazione del paper 2403.18721.html
# Paper elaborati:  61, actual paper: 2403.18811.html
# Elaborazione del paper 2403.18811.html
# Paper elaborati:  62, actual paper: 2403.19224.html
# Elaborazione del paper 2403.19224.html
# Paper elaborati:  63, actual paper: 2403.19634.html
# Elaborazione del paper 2403.19634.html
# Paper elaborati:  64, actual paper: 2403.19709.html
# Elaborazione del paper 2403.19709.html
# Paper elaborati:  65, actual paper: 2403.20262.html
# Elaborazione del paper 2403.20262.html
# Paper elaborati:  66, actual paper: 2404.00124.html
# Elaborazione del paper 2404.00124.html
# Paper elaborati:  67, actual paper: 2404.00368.html
# Elaborazione del paper 2404.00368.html
# Paper elaborati:  68, actual paper: 2404.00471.html
# Elaborazione del paper 2404.00471.html
# Paper elaborati:  69, actual paper: 2404.00989.html
# Elaborazione del paper 2404.00989.html
# Paper elaborati:  70, actual paper: 2404.01657.html
# Elaborazione del paper 2404.01657.html
# Paper elaborati:  71, actual paper: 2404.01862.html
# Elaborazione del paper 2404.01862.html
# Paper elaborati:  72, actual paper: 2404.02052.html
# Elaborazione del paper 2404.02052.html
# Paper elaborati:  73, actual paper: 2404.02098.html
# Elaborazione del paper 2404.02098.html
# Paper elaborati:  74, actual paper: 2404.02408.html
# Elaborazione del paper 2404.02408.html
# Paper elaborati:  75, actual paper: 2404.03179.html
# Elaborazione del paper 2404.03179.html
# Paper elaborati:  76, actual paper: 2404.06079.html
# Elaborazione del paper 2404.06079.html
# Paper elaborati:  77, actual paper: 2404.06292.html
# Elaborazione del paper 2404.06292.html
# Paper elaborati:  78, actual paper: 2404.06702.html
# Elaborazione del paper 2404.06702.html
# Paper elaborati:  79, actual paper: 2404.07226.html
# Elaborazione del paper 2404.07226.html
# Paper elaborati:  80, actual paper: 2404.07336.html
# Elaborazione del paper 2404.07336.html
# Paper elaborati:  81, actual paper: 2404.07341.html
# Elaborazione del paper 2404.07341.html
# Paper elaborati:  82, actual paper: 2404.07989.html
# Elaborazione del paper 2404.07989.html
# Paper elaborati:  83, actual paper: 2404.08011.html
# Elaborazione del paper 2404.08011.html
# Paper elaborati:  84, actual paper: 2404.08264.html
# Elaborazione del paper 2404.08264.html
# Paper elaborati:  85, actual paper: 2404.08368.html
# Elaborazione del paper 2404.08368.html
# Paper elaborati:  86, actual paper: 2404.09342.html
# Elaborazione del paper 2404.09342.html
# Paper elaborati:  87, actual paper: 2404.09754.html
# Elaborazione del paper 2404.09754.html
# Paper elaborati:  88, actual paper: 2404.09841.html
# Elaborazione del paper 2404.09841.html
# Paper elaborati:  89, actual paper: 2404.10180.html
# Elaborazione del paper 2404.10180.html
# Paper elaborati:  90, actual paper: 2404.10667.html
# Elaborazione del paper 2404.10667.html
# Paper elaborati:  91, actual paper: 2404.10904.html
# Elaborazione del paper 2404.10904.html
# Paper elaborati:  92, actual paper: 2404.10989.html
# Elaborazione del paper 2404.10989.html
# Paper elaborati:  93, actual paper: 2404.12062.html
# Elaborazione del paper 2404.12062.html
# Paper elaborati:  94, actual paper: 2404.12628.html
# Elaborazione del paper 2404.12628.html
# Paper elaborati:  95, actual paper: 2404.12725.html
# Elaborazione del paper 2404.12725.html
# Paper elaborati:  96, actual paper: 2404.13509.html
# Elaborazione del paper 2404.13509.html
# Paper elaborati:  97, actual paper: 2404.14716.html
# Elaborazione del paper 2404.14716.html
# Paper elaborati:  98, actual paper: 2404.15168.html
# Elaborazione del paper 2404.15168.html
# Paper elaborati:  99, actual paper: 2404.16216.html
# Elaborazione del paper 2404.16216.html
# Paper elaborati:  100, actual paper: 2404.16407.html
# Elaborazione del paper 2404.16407.html
# Paper elaborati:  101, actual paper: 2404.16547.html
# Elaborazione del paper 2404.16547.html
# Paper elaborati:  102, actual paper: 2404.16743.html
# Elaborazione del paper 2404.16743.html
# Paper elaborati:  103, actual paper: 2404.16905.html
# Elaborazione del paper 2404.16905.html
# Paper elaborati:  104, actual paper: 2404.17394.html
# Elaborazione del paper 2404.17394.html
# Paper elaborati:  105, actual paper: 2404.17810.html
# Elaborazione del paper 2404.17810.html
# Paper elaborati:  106, actual paper: 2404.17968.html
# Elaborazione del paper 2404.17968.html
# Paper elaborati:  107, actual paper: 2404.18514.html
# Elaborazione del paper 2404.18514.html
# Paper elaborati:  108, actual paper: 2404.18739.html
# Elaborazione del paper 2404.18739.html
# Paper elaborati:  109, actual paper: 2404.18976.html
# Elaborazione del paper 2404.18976.html
# Paper elaborati:  110, actual paper: 2404.19214.html
# Elaborazione del paper 2404.19214.html
# Paper elaborati:  111, actual paper: 2404.19277.html
# Elaborazione del paper 2404.19277.html
# Paper elaborati:  112, actual paper: 2404.19310.html
# Elaborazione del paper 2404.19310.html
# Paper elaborati:  113, actual paper: 2404.19615.html
# Elaborazione del paper 2404.19615.html
# Paper elaborati:  114, actual paper: 2404.19622.html
# Elaborazione del paper 2404.19622.html
# Paper elaborati:  115, actual paper: 2405.00223.html
# Elaborazione del paper 2405.00223.html
# Paper elaborati:  116, actual paper: 2405.00384.html
# Elaborazione del paper 2405.00384.html
# Paper elaborati:  117, actual paper: 2405.01293.html
# Elaborazione del paper 2405.01293.html
# Paper elaborati:  118, actual paper: 2405.01730.html
# Elaborazione del paper 2405.01730.html
# Paper elaborati:  119, actual paper: 2405.02132.html
# Elaborazione del paper 2405.02132.html
# Paper elaborati:  120, actual paper: 2405.03152.html
# Elaborazione del paper 2405.03152.html
# Paper elaborati:  121, actual paper: 2405.03484.html
# Elaborazione del paper 2405.03484.html
# Paper elaborati:  122, actual paper: 2405.04096.html
# Elaborazione del paper 2405.04096.html
# Paper elaborati:  123, actual paper: 2405.04327.html
# Elaborazione del paper 2405.04327.html
# Paper elaborati:  124, actual paper: 2405.04485.html
# Elaborazione del paper 2405.04485.html
# Paper elaborati:  125, actual paper: 2405.05498.html
# Elaborazione del paper 2405.05498.html
# Paper elaborati:  126, actual paper: 2405.06368.html
# Elaborazione del paper 2405.06368.html
# Paper elaborati:  127, actual paper: 2405.06665.html
# Elaborazione del paper 2405.06665.html
# Paper elaborati:  128, actual paper: 2405.06995.html
# Elaborazione del paper 2405.06995.html
# Paper elaborati:  129, actual paper: 2405.07354.html
# Elaborazione del paper 2405.07354.html
# Paper elaborati:  130, actual paper: 2405.07930.html
# Elaborazione del paper 2405.07930.html
# Paper elaborati:  131, actual paper: 2405.08295.html
# Elaborazione del paper 2405.08295.html
# Paper elaborati:  132, actual paper: 2405.09708.html
# Elaborazione del paper 2405.09708.html
# Paper elaborati:  133, actual paper: 2405.09814.html
# Elaborazione del paper 2405.09814.html
# Paper elaborati:  134, actual paper: 2405.10025.html
# Elaborazione del paper 2405.10025.html
# Paper elaborati:  135, actual paper: 2405.11519.html
# Elaborazione del paper 2405.11519.html
# Paper elaborati:  136, actual paper: 2405.12221.html
# Elaborazione del paper 2405.12221.html
# Paper elaborati:  137, actual paper: 2405.12609.html
# Elaborazione del paper 2405.12609.html
# Paper elaborati:  138, actual paper: 2405.12983.html
# Elaborazione del paper 2405.12983.html
# Paper elaborati:  139, actual paper: 2405.13001.html
# Elaborazione del paper 2405.13001.html
# Paper elaborati:  140, actual paper: 2405.13011.html
# Elaborazione del paper 2405.13011.html
# Paper elaborati:  141, actual paper: 2405.13017.html
# Elaborazione del paper 2405.13017.html
# Paper elaborati:  142, actual paper: 2405.13018.html
# Elaborazione del paper 2405.13018.html
# Paper elaborati:  143, actual paper: 2405.13166.html
# Elaborazione del paper 2405.13166.html
# Paper elaborati:  144, actual paper: 2405.13344.html
# Elaborazione del paper 2405.13344.html
# Paper elaborati:  145, actual paper: 2405.13379.html
# Elaborazione del paper 2405.13379.html
# Paper elaborati:  146, actual paper: 2405.13514.html
# Elaborazione del paper 2405.13514.html
# Paper elaborati:  147, actual paper: 2405.13903.html
# Elaborazione del paper 2405.13903.html
# Paper elaborati:  148, actual paper: 2405.13924.html
# Elaborazione del paper 2405.13924.html
# Paper elaborati:  149, actual paper: 2405.14116.html
# Elaborazione del paper 2405.14116.html
# Paper elaborati:  150, actual paper: 2405.14161.html
# Elaborazione del paper 2405.14161.html
# Paper elaborati:  151, actual paper: 2405.14259.html
# Elaborazione del paper 2405.14259.html
# Paper elaborati:  152, actual paper: 2405.14791.html
# Elaborazione del paper 2405.14791.html
# Paper elaborati:  153, actual paper: 2405.15097.html
# Elaborazione del paper 2405.15097.html
# Paper elaborati:  154, actual paper: 2405.15216.html
# Elaborazione del paper 2405.15216.html
# Paper elaborati:  155, actual paper: 2405.16000.html
# Elaborazione del paper 2405.16000.html
# Paper elaborati:  156, actual paper: 2405.16677.html
# Elaborazione del paper 2405.16677.html
# Paper elaborati:  157, actual paper: 2405.17376.html
# Elaborazione del paper 2405.17376.html
# Paper elaborati:  158, actual paper: 2405.17842.html
# Elaborazione del paper 2405.17842.html
# Paper elaborati:  159, actual paper: 2405.17927.html
# Elaborazione del paper 2405.17927.html
# Paper elaborati:  160, actual paper: 2405.18213.html
# Elaborazione del paper 2405.18213.html
# Paper elaborati:  161, actual paper: 2405.18537.html
# Elaborazione del paper 2405.18537.html
# Paper elaborati:  162, actual paper: 2405.18726.html
# Elaborazione del paper 2405.18726.html
# Paper elaborati:  163, actual paper: 2405.20402.html
# Elaborazione del paper 2405.20402.html
# Paper elaborati:  164, actual paper: 2406.00022.html
# Elaborazione del paper 2406.00022.html
# Paper elaborati:  165, actual paper: 2406.00320.html
# Elaborazione del paper 2406.00320.html
# Paper elaborati:  166, actual paper: 2406.00495.html
# Elaborazione del paper 2406.00495.html
# Paper elaborati:  167, actual paper: 2406.00898.html
# Elaborazione del paper 2406.00898.html
# Paper elaborati:  168, actual paper: 2406.00899.html
# Elaborazione del paper 2406.00899.html
# Paper elaborati:  169, actual paper: 2406.01624.html
# Elaborazione del paper 2406.01624.html
# Paper elaborati:  170, actual paper: 2406.02166.html
# Elaborazione del paper 2406.02166.html
# Paper elaborati:  171, actual paper: 2406.02488.html
# Elaborazione del paper 2406.02488.html
# Paper elaborati:  172, actual paper: 2406.02555.html
# Elaborazione del paper 2406.02555.html
# Paper elaborati:  173, actual paper: 2406.02562.html
# Elaborazione del paper 2406.02562.html
# Paper elaborati:  174, actual paper: 2406.02565.html
# Elaborazione del paper 2406.02565.html
# Paper elaborati:  175, actual paper: 2406.02921.html
# Elaborazione del paper 2406.02921.html
# Paper elaborati:  176, actual paper: 2406.02925.html
# Elaborazione del paper 2406.02925.html
# Paper elaborati:  177, actual paper: 2406.02950.html
# Elaborazione del paper 2406.02950.html
# Paper elaborati:  178, actual paper: 2406.02951.html
# Elaborazione del paper 2406.02951.html
# Paper elaborati:  179, actual paper: 2406.03235.html
# Elaborazione del paper 2406.03235.html
# Paper elaborati:  180, actual paper: 2406.03240.html
# Elaborazione del paper 2406.03240.html
# Paper elaborati:  181, actual paper: 2406.03274.html
# Elaborazione del paper 2406.03274.html
# Paper elaborati:  182, actual paper: 2406.03814.html
# Elaborazione del paper 2406.03814.html
# Paper elaborati:  183, actual paper: 2406.04240.html
# Elaborazione del paper 2406.04240.html
# Paper elaborati:  184, actual paper: 2406.04269.html
# Elaborazione del paper 2406.04269.html
# Paper elaborati:  185, actual paper: 2406.04353.html
# Elaborazione del paper 2406.04353.html
# Paper elaborati:  186, actual paper: 2406.04512.html
# Elaborazione del paper 2406.04512.html
# Paper elaborati:  187, actual paper: 2406.04541.html
# Elaborazione del paper 2406.04541.html
# Paper elaborati:  188, actual paper: 2406.04595.html
# Elaborazione del paper 2406.04595.html
# Paper elaborati:  189, actual paper: 2406.04791.html
# Elaborazione del paper 2406.04791.html
# Paper elaborati:  190, actual paper: 2406.05661.html
# Elaborazione del paper 2406.05661.html
# Paper elaborati:  191, actual paper: 2406.05784.html
# Elaborazione del paper 2406.05784.html
# Paper elaborati:  192, actual paper: 2406.06220.html
# Elaborazione del paper 2406.06220.html
# Paper elaborati:  193, actual paper: 2406.06302.html
# Elaborazione del paper 2406.06302.html
# Paper elaborati:  194, actual paper: 2406.06401.html
# Elaborazione del paper 2406.06401.html
# Paper elaborati:  195, actual paper: 2406.06438.html
# Elaborazione del paper 2406.06438.html
# Paper elaborati:  196, actual paper: 2406.06798.html
# Elaborazione del paper 2406.06798.html
# Paper elaborati:  197, actual paper: 2406.07162.html
# Elaborazione del paper 2406.07162.html
# Paper elaborati:  198, actual paper: 2406.07256.html
# Elaborazione del paper 2406.07256.html
# Paper elaborati:  199, actual paper: 2406.07421.html
# Elaborazione del paper 2406.07421.html
# Paper elaborati:  200, actual paper: 2406.07437.html
# Elaborazione del paper 2406.07437.html
# Paper elaborati:  201, actual paper: 2406.07532.html
# Elaborazione del paper 2406.07532.html
# Paper elaborati:  202, actual paper: 2406.07801.html
# Elaborazione del paper 2406.07801.html
# Paper elaborati:  203, actual paper: 2406.07867.html
# Elaborazione del paper 2406.07867.html
# Paper elaborati:  204, actual paper: 2406.07871.html
# Elaborazione del paper 2406.07871.html
# Paper elaborati:  205, actual paper: 2406.07900.html
# Elaborazione del paper 2406.07900.html
# Paper elaborati:  206, actual paper: 2406.07914.html
# Elaborazione del paper 2406.07914.html
# Paper elaborati:  207, actual paper: 2406.08096.html
# Elaborazione del paper 2406.08096.html
# Paper elaborati:  208, actual paper: 2406.08207.html
# Elaborazione del paper 2406.08207.html
# Paper elaborati:  209, actual paper: 2406.08266.html
# Elaborazione del paper 2406.08266.html
# Paper elaborati:  210, actual paper: 2406.08336.html
# Elaborazione del paper 2406.08336.html
# Paper elaborati:  211, actual paper: 2406.08380.html
# Elaborazione del paper 2406.08380.html
# Paper elaborati:  212, actual paper: 2406.08396.html
# Elaborazione del paper 2406.08396.html
# Paper elaborati:  213, actual paper: 2406.08568.html
# Elaborazione del paper 2406.08568.html
# Paper elaborati:  214, actual paper: 2406.08641.html
# Elaborazione del paper 2406.08641.html
# Paper elaborati:  215, actual paper: 2406.08801.html
# Elaborazione del paper 2406.08801.html
# Paper elaborati:  216, actual paper: 2406.08931.html
# Elaborazione del paper 2406.08931.html
# Paper elaborati:  217, actual paper: 2406.09156.html
# Elaborazione del paper 2406.09156.html
# Paper elaborati:  218, actual paper: 2406.09202.html
# Elaborazione del paper 2406.09202.html
# Paper elaborati:  219, actual paper: 2406.09272.html
# Elaborazione del paper 2406.09272.html
# Paper elaborati:  220, actual paper: 2406.09290.html
# Elaborazione del paper 2406.09290.html
# Paper elaborati:  221, actual paper: 2406.09326.html
# Elaborazione del paper 2406.09326.html
# Paper elaborati:  222, actual paper: 2406.09425.html
# Elaborazione del paper 2406.09425.html
# Paper elaborati:  223, actual paper: 2406.09443.html
# Elaborazione del paper 2406.09443.html
# Paper elaborati:  224, actual paper: 2406.09494.html
# Elaborazione del paper 2406.09494.html
# Paper elaborati:  225, actual paper: 2406.09569.html
# Elaborazione del paper 2406.09569.html
# Paper elaborati:  226, actual paper: 2406.09676.html
# Elaborazione del paper 2406.09676.html
# Paper elaborati:  227, actual paper: 2406.09873.html
# Elaborazione del paper 2406.09873.html
# Paper elaborati:  228, actual paper: 2406.09933.html
# Elaborazione del paper 2406.09933.html
# Paper elaborati:  229, actual paper: 2406.10052.html
# Elaborazione del paper 2406.10052.html
# Paper elaborati:  230, actual paper: 2406.10082.html
# Elaborazione del paper 2406.10082.html
# Paper elaborati:  231, actual paper: 2406.10083.html
# Elaborazione del paper 2406.10083.html
# Paper elaborati:  232, actual paper: 2406.10152.html
# Elaborazione del paper 2406.10152.html
# Paper elaborati:  233, actual paper: 2406.10177.html
# Elaborazione del paper 2406.10177.html
# Paper elaborati:  234, actual paper: 2406.10313.html
# Elaborazione del paper 2406.10313.html
# Paper elaborati:  235, actual paper: 2406.10598.html
# Elaborazione del paper 2406.10598.html
# Paper elaborati:  236, actual paper: 2406.10719.html
# Elaborazione del paper 2406.10719.html
# Paper elaborati:  237, actual paper: 2406.10932.html
# Elaborazione del paper 2406.10932.html
# Paper elaborati:  238, actual paper: 2406.10993.html
# Elaborazione del paper 2406.10993.html
# Paper elaborati:  239, actual paper: 2406.11016.html
# Elaborazione del paper 2406.11016.html
# Paper elaborati:  240, actual paper: 2406.11022.html
# Elaborazione del paper 2406.11022.html
# Paper elaborati:  241, actual paper: 2406.11064.html
# Elaborazione del paper 2406.11064.html
# Paper elaborati:  242, actual paper: 2406.12233.html
# Elaborazione del paper 2406.12233.html
# Paper elaborati:  243, actual paper: 2406.12387.html
# Elaborazione del paper 2406.12387.html
# Paper elaborati:  244, actual paper: 2406.12544.html
# Elaborazione del paper 2406.12544.html
# Paper elaborati:  245, actual paper: 2406.12611.html
# Elaborazione del paper 2406.12611.html
# Paper elaborati:  246, actual paper: 2406.12621.html
# Elaborazione del paper 2406.12621.html
# Paper elaborati:  247, actual paper: 2406.13268.html
# Elaborazione del paper 2406.13268.html
# Paper elaborati:  248, actual paper: 2406.13337.html
# Elaborazione del paper 2406.13337.html
# Paper elaborati:  249, actual paper: 2406.13431.html
# Elaborazione del paper 2406.13431.html
# Paper elaborati:  250, actual paper: 2406.13502.html
# Elaborazione del paper 2406.13502.html
# Paper elaborati:  251, actual paper: 2406.13842.html
# Elaborazione del paper 2406.13842.html
# Paper elaborati:  252, actual paper: 2406.14266.html
# Elaborazione del paper 2406.14266.html
# Paper elaborati:  253, actual paper: 2406.14272.html
# Elaborazione del paper 2406.14272.html
# Paper elaborati:  254, actual paper: 2406.14294.html
# Elaborazione del paper 2406.14294.html
# Paper elaborati:  255, actual paper: 2406.14701.html
# Elaborazione del paper 2406.14701.html
# Paper elaborati:  256, actual paper: 2406.14747.html
# Elaborazione del paper 2406.14747.html
# Paper elaborati:  257, actual paper: 2406.14856.html
# Elaborazione del paper 2406.14856.html
# Paper elaborati:  258, actual paper: 2406.14890.html
# Elaborazione del paper 2406.14890.html
# Paper elaborati:  259, actual paper: 2406.15704.html
# Elaborazione del paper 2406.15704.html
# Paper elaborati:  260, actual paper: 2406.15723.html
# Elaborazione del paper 2406.15723.html
# Paper elaborati:  261, actual paper: 2406.15754.html
# Elaborazione del paper 2406.15754.html
# Paper elaborati:  262, actual paper: 2406.16107.html
# Elaborazione del paper 2406.16107.html
# Paper elaborati:  263, actual paper: 2406.16777.html
# Elaborazione del paper 2406.16777.html
# Paper elaborati:  264, actual paper: 2406.16808.html
# Elaborazione del paper 2406.16808.html
# Paper elaborati:  265, actual paper: 2406.17124.html
# Elaborazione del paper 2406.17124.html
# Paper elaborati:  266, actual paper: 2406.17272.html
# Elaborazione del paper 2406.17272.html
# Paper elaborati:  267, actual paper: 2406.17618.html
# Elaborazione del paper 2406.17618.html
# Paper elaborati:  268, actual paper: 2406.17926.html
# Elaborazione del paper 2406.17926.html
# Paper elaborati:  269, actual paper: 2406.18021.html
# Elaborazione del paper 2406.18021.html
# Paper elaborati:  270, actual paper: 2406.18065.html
# Elaborazione del paper 2406.18065.html
# Paper elaborati:  271, actual paper: 2406.18120.html
# Elaborazione del paper 2406.18120.html
# Paper elaborati:  272, actual paper: 2406.18301.html
# Elaborazione del paper 2406.18301.html
# Paper elaborati:  273, actual paper: 2406.18373.html
# Elaborazione del paper 2406.18373.html
# Paper elaborati:  274, actual paper: 2406.18972.html
# Elaborazione del paper 2406.18972.html
# Paper elaborati:  275, actual paper: 2406.19311.html
# Elaborazione del paper 2406.19311.html
# Paper elaborati:  276, actual paper: 2406.19564.html
# Elaborazione del paper 2406.19564.html
# Paper elaborati:  277, actual paper: 2406.19674.html
# Elaborazione del paper 2406.19674.html
# Paper elaborati:  278, actual paper: 2407.00418.html
# Elaborazione del paper 2407.00418.html
# Paper elaborati:  279, actual paper: 2407.00465.html
# Elaborazione del paper 2407.00465.html
# Paper elaborati:  280, actual paper: 2407.01034.html
# Elaborazione del paper 2407.01034.html
# Paper elaborati:  281, actual paper: 2407.01494.html
# Elaborazione del paper 2407.01494.html
# Paper elaborati:  282, actual paper: 2407.01851.html
# Elaborazione del paper 2407.01851.html
# Paper elaborati:  283, actual paper: 2407.01909.html
# Elaborazione del paper 2407.01909.html
# Paper elaborati:  284, actual paper: 2407.02004.html
# Elaborazione del paper 2407.02004.html
# Paper elaborati:  285, actual paper: 2407.02052.html
# Elaborazione del paper 2407.02052.html
# Paper elaborati:  286, actual paper: 2407.02318.html
# Elaborazione del paper 2407.02318.html
# Paper elaborati:  287, actual paper: 2407.02543.html
# Elaborazione del paper 2407.02543.html
# Paper elaborati:  288, actual paper: 2407.03026.html
# Elaborazione del paper 2407.03026.html
# Paper elaborati:  289, actual paper: 2407.03440.html
# Elaborazione del paper 2407.03440.html
# Paper elaborati:  290, actual paper: 2407.03470.html
# Elaborazione del paper 2407.03470.html
# Paper elaborati:  291, actual paper: 2407.03495.html
# Elaborazione del paper 2407.03495.html
# Paper elaborati:  292, actual paper: 2407.03718.html
# Elaborazione del paper 2407.03718.html
# Paper elaborati:  293, actual paper: 2407.03736.html
# Elaborazione del paper 2407.03736.html
# Paper elaborati:  294, actual paper: 2407.03809.html
# Elaborazione del paper 2407.03809.html
# Paper elaborati:  295, actual paper: 2407.04047.html
# Elaborazione del paper 2407.04047.html
# Paper elaborati:  296, actual paper: 2407.04051.html
# Elaborazione del paper 2407.04051.html
# Paper elaborati:  297, actual paper: 2407.04291.html
# Elaborazione del paper 2407.04291.html
# Paper elaborati:  298, actual paper: 2407.04482.html
# Elaborazione del paper 2407.04482.html
# Paper elaborati:  299, actual paper: 2407.04641.html
# Elaborazione del paper 2407.04641.html
# Paper elaborati:  300, actual paper: 2407.04652.html
# Elaborazione del paper 2407.04652.html
# Paper elaborati:  301, actual paper: 2407.04675.html
# Elaborazione del paper 2407.04675.html
# Paper elaborati:  302, actual paper: 2407.05407.html
# Elaborazione del paper 2407.05407.html
# Paper elaborati:  303, actual paper: 2407.05577.html
# Elaborazione del paper 2407.05577.html
# Paper elaborati:  304, actual paper: 2407.05782.html
# Elaborazione del paper 2407.05782.html
# Paper elaborati:  305, actual paper: 2407.05980.html
# Elaborazione del paper 2407.05980.html
# Paper elaborati:  306, actual paper: 2407.06060.html
# Elaborazione del paper 2407.06060.html
# Paper elaborati:  307, actual paper: 2407.06606.html
# Elaborazione del paper 2407.06606.html
# Paper elaborati:  308, actual paper: 2407.06957.html
# Elaborazione del paper 2407.06957.html
# Paper elaborati:  309, actual paper: 2407.08130.html
# Elaborazione del paper 2407.08130.html
# Paper elaborati:  310, actual paper: 2407.08403.html
# Elaborazione del paper 2407.08403.html
# Paper elaborati:  311, actual paper: 2407.08658.html
# Elaborazione del paper 2407.08658.html
# Paper elaborati:  312, actual paper: 2407.08717.html
# Elaborazione del paper 2407.08717.html
# Paper elaborati:  313, actual paper: 2407.09489.html
# Elaborazione del paper 2407.09489.html
# Paper elaborati:  314, actual paper: 2407.09732.html
# Elaborazione del paper 2407.09732.html
# Paper elaborati:  315, actual paper: 2407.09817.html
# Elaborazione del paper 2407.09817.html
# Paper elaborati:  316, actual paper: 2407.10255.html
# Elaborazione del paper 2407.10255.html
# Paper elaborati:  317, actual paper: 2407.10303.html
# Elaborazione del paper 2407.10303.html
# Paper elaborati:  318, actual paper: 2407.10387.html
# Elaborazione del paper 2407.10387.html
# Paper elaborati:  319, actual paper: 2407.10603.html
# Elaborazione del paper 2407.10603.html
# Paper elaborati:  320, actual paper: 2407.11345.html
# Elaborazione del paper 2407.11345.html
# Paper elaborati:  321, actual paper: 2407.11641.html
# Elaborazione del paper 2407.11641.html
# Paper elaborati:  322, actual paper: 2407.11650.html
# Elaborazione del paper 2407.11650.html
# Paper elaborati:  323, actual paper: 2407.12000.html
# Elaborazione del paper 2407.12000.html
# Paper elaborati:  324, actual paper: 2407.12240.html
# Elaborazione del paper 2407.12240.html
# Paper elaborati:  325, actual paper: 2407.12380.html
# Elaborazione del paper 2407.12380.html
# Paper elaborati:  326, actual paper: 2407.12501.html
# Elaborazione del paper 2407.12501.html
# Paper elaborati:  327, actual paper: 2407.12817.html
# Elaborazione del paper 2407.12817.html
# Paper elaborati:  328, actual paper: 2407.13083.html
# Elaborazione del paper 2407.13083.html
# Paper elaborati:  329, actual paper: 2407.13095.html
# Elaborazione del paper 2407.13095.html
# Paper elaborati:  330, actual paper: 2407.13300.html
# Elaborazione del paper 2407.13300.html
# Paper elaborati:  331, actual paper: 2407.13676.html
# Elaborazione del paper 2407.13676.html
# Paper elaborati:  332, actual paper: 2407.13782.html
# Elaborazione del paper 2407.13782.html
# Paper elaborati:  333, actual paper: 2407.13982.html
# Elaborazione del paper 2407.13982.html
# Paper elaborati:  334, actual paper: 2407.14573.html
# Elaborazione del paper 2407.14573.html
# Paper elaborati:  335, actual paper: 2407.15798.html
# Elaborazione del paper 2407.15798.html
# Paper elaborati:  336, actual paper: 2407.15835.html
# Elaborazione del paper 2407.15835.html
# Paper elaborati:  337, actual paper: 2407.16370.html
# Elaborazione del paper 2407.16370.html
# Paper elaborati:  338, actual paper: 2407.16537.html
# Elaborazione del paper 2407.16537.html
# Paper elaborati:  339, actual paper: 2407.16664.html
# Elaborazione del paper 2407.16664.html
# Paper elaborati:  340, actual paper: 2407.17160.html
# Elaborazione del paper 2407.17160.html
# Paper elaborati:  341, actual paper: 2407.17605.html
# Elaborazione del paper 2407.17605.html
# Paper elaborati:  342, actual paper: 2407.17716.html
# Elaborazione del paper 2407.17716.html
# Paper elaborati:  343, actual paper: 2407.17852.html
# Elaborazione del paper 2407.17852.html
# Paper elaborati:  344, actual paper: 2407.17874.html
# Elaborazione del paper 2407.17874.html
# Paper elaborati:  345, actual paper: 2407.17997.html
# Elaborazione del paper 2407.17997.html
# Paper elaborati:  346, actual paper: 2407.18058.html
# Elaborazione del paper 2407.18058.html
# Paper elaborati:  347, actual paper: 2407.18332.html
# Elaborazione del paper 2407.18332.html
# Paper elaborati:  348, actual paper: 2407.18985.html
# Elaborazione del paper 2407.18985.html
# Paper elaborati:  349, actual paper: 2407.20111.html
# Elaborazione del paper 2407.20111.html
# Paper elaborati:  350, actual paper: 2407.20535.html
# Elaborazione del paper 2407.20535.html
# Paper elaborati:  351, actual paper: 2407.21174.html
# Elaborazione del paper 2407.21174.html
# Paper elaborati:  352, actual paper: 2407.21476.html
# Elaborazione del paper 2407.21476.html
# Paper elaborati:  353, actual paper: 2407.21783.html
# Elaborazione del paper 2407.21783.html
# Paper elaborati:  354, actual paper: 2408.00325.html
# Elaborazione del paper 2408.00325.html
# Paper elaborati:  355, actual paper: 2408.01096.html
# Elaborazione del paper 2408.01096.html
# Paper elaborati:  356, actual paper: 2408.01532.html
# Elaborazione del paper 2408.01532.html
# Paper elaborati:  357, actual paper: 2408.01732.html
# Elaborazione del paper 2408.01732.html
# Paper elaborati:  358, actual paper: 2408.02178.html
# Elaborazione del paper 2408.02178.html
# Paper elaborati:  359, actual paper: 2408.02369.html
# Elaborazione del paper 2408.02369.html
# Paper elaborati:  360, actual paper: 2408.02945.html
# Elaborazione del paper 2408.02945.html
# Paper elaborati:  361, actual paper: 2408.02978.html
# Elaborazione del paper 2408.02978.html
# Paper elaborati:  362, actual paper: 2408.04174.html
# Elaborazione del paper 2408.04174.html
# Paper elaborati:  363, actual paper: 2408.04967.html
# Elaborazione del paper 2408.04967.html
# Paper elaborati:  364, actual paper: 2408.05554.html
# Elaborazione del paper 2408.05554.html
# Paper elaborati:  365, actual paper: 2408.05769.html
# Elaborazione del paper 2408.05769.html
# Paper elaborati:  366, actual paper: 2408.06264.html
# Elaborazione del paper 2408.06264.html
# Paper elaborati:  367, actual paper: 2408.06484.html
# Elaborazione del paper 2408.06484.html
# Paper elaborati:  368, actual paper: 2408.06753.html
# Elaborazione del paper 2408.06753.html
# Paper elaborati:  369, actual paper: 2408.07081.html
# Elaborazione del paper 2408.07081.html
# Paper elaborati:  370, actual paper: 2408.07851.html
# Elaborazione del paper 2408.07851.html
# Paper elaborati:  371, actual paper: 2408.08027.html
# Elaborazione del paper 2408.08027.html
# Paper elaborati:  372, actual paper: 2408.09215.html
# Elaborazione del paper 2408.09215.html
# Paper elaborati:  373, actual paper: 2408.09347.html
# Elaborazione del paper 2408.09347.html
# Paper elaborati:  374, actual paper: 2408.09397.html
# Elaborazione del paper 2408.09397.html
# Paper elaborati:  375, actual paper: 2408.09453.html
# Elaborazione del paper 2408.09453.html
# Paper elaborati:  376, actual paper: 2408.09802.html
# Elaborazione del paper 2408.09802.html
# Paper elaborati:  377, actual paper: 2408.10207.html
# Elaborazione del paper 2408.10207.html
# Paper elaborati:  378, actual paper: 2408.10240.html
# Elaborazione del paper 2408.10240.html
# Paper elaborati:  379, actual paper: 2408.10500.html
# Elaborazione del paper 2408.10500.html
# Paper elaborati:  380, actual paper: 2408.10524.html
# Elaborazione del paper 2408.10524.html
# Paper elaborati:  381, actual paper: 2408.11258.html
# Elaborazione del paper 2408.11258.html
# Paper elaborati:  382, actual paper: 2408.11593.html
# Elaborazione del paper 2408.11593.html
# Paper elaborati:  383, actual paper: 2408.11849.html
# Elaborazione del paper 2408.11849.html
# Paper elaborati:  384, actual paper: 2408.11858.html
# Elaborazione del paper 2408.11858.html
# Paper elaborati:  385, actual paper: 2408.11915.html
# Elaborazione del paper 2408.11915.html
# Paper elaborati:  386, actual paper: 2408.11956.html
# Elaborazione del paper 2408.11956.html
# Paper elaborati:  387, actual paper: 2408.12102.html
# Elaborazione del paper 2408.12102.html
# Paper elaborati:  388, actual paper: 2408.12279.html
# Elaborazione del paper 2408.12279.html
# Paper elaborati:  389, actual paper: 2408.12734.html
# Elaborazione del paper 2408.12734.html
# Paper elaborati:  390, actual paper: 2408.12885.html
# Elaborazione del paper 2408.12885.html
# Paper elaborati:  391, actual paper: 2408.13008.html
# Elaborazione del paper 2408.13008.html
# Paper elaborati:  392, actual paper: 2408.13106.html
# Elaborazione del paper 2408.13106.html
# Paper elaborati:  393, actual paper: 2408.13201.html
# Elaborazione del paper 2408.13201.html
# Paper elaborati:  394, actual paper: 2408.13341.html
# Elaborazione del paper 2408.13341.html
# Paper elaborati:  395, actual paper: 2408.13585.html
# Elaborazione del paper 2408.13585.html
# Paper elaborati:  396, actual paper: 2408.13644.html
# Elaborazione del paper 2408.13644.html
# Paper elaborati:  397, actual paper: 2408.13739.html
# Elaborazione del paper 2408.13739.html
# Paper elaborati:  398, actual paper: 2408.13891.html
# Elaborazione del paper 2408.13891.html
# Paper elaborati:  399, actual paper: 2408.13920.html
# Elaborazione del paper 2408.13920.html
# Paper elaborati:  400, actual paper: 2408.14080.html
# Elaborazione del paper 2408.14080.html
# Paper elaborati:  401, actual paper: 2408.14143.html
# Elaborazione del paper 2408.14143.html
# Paper elaborati:  402, actual paper: 2408.14418.html
# Elaborazione del paper 2408.14418.html
# Paper elaborati:  403, actual paper: 2408.14585.html
# Elaborazione del paper 2408.14585.html
# Paper elaborati:  404, actual paper: 2408.14886.html
# Elaborazione del paper 2408.14886.html
# Paper elaborati:  405, actual paper: 2408.14887.html
# Elaborazione del paper 2408.14887.html
# Paper elaborati:  406, actual paper: 2408.14991.html
# Elaborazione del paper 2408.14991.html
# Paper elaborati:  407, actual paper: 2408.15553.html
# Elaborazione del paper 2408.15553.html
# Paper elaborati:  408, actual paper: 2408.15585.html
# Elaborazione del paper 2408.15585.html
# Paper elaborati:  409, actual paper: 2408.15667.html
# Elaborazione del paper 2408.15667.html
# Paper elaborati:  410, actual paper: 2408.15803.html
# Elaborazione del paper 2408.15803.html
# Paper elaborati:  411, actual paper: 2408.16180.html
# Elaborazione del paper 2408.16180.html
# Paper elaborati:  412, actual paper: 2408.16589.html
# Elaborazione del paper 2408.16589.html
# Paper elaborati:  413, actual paper: 2408.17142.html
# Elaborazione del paper 2408.17142.html
# Paper elaborati:  414, actual paper: 2408.17431.html
# Elaborazione del paper 2408.17431.html
# Paper elaborati:  415, actual paper: 2409.00151.html
# Elaborazione del paper 2409.00151.html
# Paper elaborati:  416, actual paper: 2409.00387.html
# Elaborazione del paper 2409.00387.html
# Paper elaborati:  417, actual paper: 2409.00587.html
# Elaborazione del paper 2409.00587.html
# Paper elaborati:  418, actual paper: 2409.00700.html
# Elaborazione del paper 2409.00700.html
# Paper elaborati:  419, actual paper: 2409.00815.html
# Elaborazione del paper 2409.00815.html
# Paper elaborati:  420, actual paper: 2409.00819.html
# Elaborazione del paper 2409.00819.html
# Paper elaborati:  421, actual paper: 2409.00946.html
# Elaborazione del paper 2409.00946.html
# Paper elaborati:  422, actual paper: 2409.01011.html
# Elaborazione del paper 2409.01011.html
# Paper elaborati:  423, actual paper: 2409.01309.html
# Elaborazione del paper 2409.01309.html
# Paper elaborati:  424, actual paper: 2409.01548.html
# Elaborazione del paper 2409.01548.html
# Paper elaborati:  425, actual paper: 2409.01813.html
# Elaborazione del paper 2409.01813.html
# Paper elaborati:  426, actual paper: 2409.02041.html
# Elaborazione del paper 2409.02041.html
# Paper elaborati:  427, actual paper: 2409.02111.html
# Elaborazione del paper 2409.02111.html
# Paper elaborati:  428, actual paper: 2409.02243.html
# Elaborazione del paper 2409.02243.html
# Paper elaborati:  429, actual paper: 2409.02565.html
# Elaborazione del paper 2409.02565.html
# Paper elaborati:  430, actual paper: 2409.02615.html
# Elaborazione del paper 2409.02615.html
# Paper elaborati:  431, actual paper: 2409.03059.html
# Elaborazione del paper 2409.03059.html
# Paper elaborati:  432, actual paper: 2409.03336.html
# Elaborazione del paper 2409.03336.html
# Paper elaborati:  433, actual paper: 2409.03605.html
# Elaborazione del paper 2409.03605.html
# Paper elaborati:  434, actual paper: 2409.04007.html
# Elaborazione del paper 2409.04007.html
# Paper elaborati:  435, actual paper: 2409.04447.html
# Elaborazione del paper 2409.04447.html
# Paper elaborati:  436, actual paper: 2409.04949.html
# Elaborazione del paper 2409.04949.html
# Paper elaborati:  437, actual paper: 2409.05004.html
# Elaborazione del paper 2409.05004.html
# Paper elaborati:  438, actual paper: 2409.05005.html
# Elaborazione del paper 2409.05005.html
# Paper elaborati:  439, actual paper: 2409.05015.html
# Elaborazione del paper 2409.05015.html
# Paper elaborati:  440, actual paper: 2409.05148.html
# Elaborazione del paper 2409.05148.html
# Paper elaborati:  441, actual paper: 2409.05307.html
# Elaborazione del paper 2409.05307.html
# Paper elaborati:  442, actual paper: 2409.05430.html
# Elaborazione del paper 2409.05430.html
# Paper elaborati:  443, actual paper: 2409.05601.html
# Elaborazione del paper 2409.05601.html
# Paper elaborati:  444, actual paper: 2409.05674.html
# Elaborazione del paper 2409.05674.html
# Paper elaborati:  445, actual paper: 2409.05750.html
# Elaborazione del paper 2409.05750.html
# Paper elaborati:  446, actual paper: 2409.05770.html
# Elaborazione del paper 2409.05770.html
# Paper elaborati:  447, actual paper: 2409.06062.html
# Elaborazione del paper 2409.06062.html
# Paper elaborati:  448, actual paper: 2409.06135.html
# Elaborazione del paper 2409.06135.html
# Paper elaborati:  449, actual paper: 2409.06222.html
# Elaborazione del paper 2409.06222.html
# Paper elaborati:  450, actual paper: 2409.06263.html
# Elaborazione del paper 2409.06263.html
# Paper elaborati:  451, actual paper: 2409.06274.html
# Elaborazione del paper 2409.06274.html
# Paper elaborati:  452, actual paper: 2409.06429.html
# Elaborazione del paper 2409.06429.html
# Paper elaborati:  453, actual paper: 2409.06580.html
# Elaborazione del paper 2409.06580.html
# Paper elaborati:  454, actual paper: 2409.07114.html
# Elaborazione del paper 2409.07114.html
# Paper elaborati:  455, actual paper: 2409.07165.html
# Elaborazione del paper 2409.07165.html
# Paper elaborati:  456, actual paper: 2409.07210.html
# Elaborazione del paper 2409.07210.html
# Paper elaborati:  457, actual paper: 2409.07255.html
# Elaborazione del paper 2409.07255.html
# Paper elaborati:  458, actual paper: 2409.07259.html
# Elaborazione del paper 2409.07259.html
# Paper elaborati:  459, actual paper: 2409.07450.html
# Elaborazione del paper 2409.07450.html
# Paper elaborati:  460, actual paper: 2409.07827.html
# Elaborazione del paper 2409.07827.html
# Paper elaborati:  461, actual paper: 2409.07966.html
# Elaborazione del paper 2409.07966.html
# Paper elaborati:  462, actual paper: 2409.07973.html
# Elaborazione del paper 2409.07973.html
# Paper elaborati:  463, actual paper: 2409.08107.html
# Elaborazione del paper 2409.08107.html
# Paper elaborati:  464, actual paper: 2409.08597.html
# Elaborazione del paper 2409.08597.html
# Paper elaborati:  465, actual paper: 2409.08711.html
# Elaborazione del paper 2409.08711.html
# Paper elaborati:  466, actual paper: 2409.08805.html
# Elaborazione del paper 2409.08805.html
# Paper elaborati:  467, actual paper: 2409.08872.html
# Elaborazione del paper 2409.08872.html
# Paper elaborati:  468, actual paper: 2409.08985.html
# Elaborazione del paper 2409.08985.html
# Paper elaborati:  469, actual paper: 2409.09067.html
# Elaborazione del paper 2409.09067.html
# Paper elaborati:  470, actual paper: 2409.09221.html
# Elaborazione del paper 2409.09221.html
# Paper elaborati:  471, actual paper: 2409.09545.html
# Elaborazione del paper 2409.09545.html
# Paper elaborati:  472, actual paper: 2409.09611.html
# Elaborazione del paper 2409.09611.html
# Paper elaborati:  473, actual paper: 2409.09785.html
# Elaborazione del paper 2409.09785.html
# Paper elaborati:  474, actual paper: 2409.09914.html
# Elaborazione del paper 2409.09914.html
# Paper elaborati:  475, actual paper: 2409.10056.html
# Elaborazione del paper 2409.10056.html
# Paper elaborati:  476, actual paper: 2409.10076.html
# Elaborazione del paper 2409.10076.html
# Paper elaborati:  477, actual paper: 2409.10177.html
# Elaborazione del paper 2409.10177.html
# Paper elaborati:  478, actual paper: 2409.10240.html
# Elaborazione del paper 2409.10240.html
# Paper elaborati:  479, actual paper: 2409.10687.html
# Elaborazione del paper 2409.10687.html
# Paper elaborati:  480, actual paper: 2409.10710.html
# Elaborazione del paper 2409.10710.html
# Paper elaborati:  481, actual paper: 2409.10849.html
# Elaborazione del paper 2409.10849.html
# Paper elaborati:  482, actual paper: 2409.10858.html
# Elaborazione del paper 2409.10858.html
# Paper elaborati:  483, actual paper: 2409.10985.html
# Elaborazione del paper 2409.10985.html
# Paper elaborati:  484, actual paper: 2409.11107.html
# Elaborazione del paper 2409.11107.html
# Paper elaborati:  485, actual paper: 2409.11214.html
# Elaborazione del paper 2409.11214.html
# Paper elaborati:  486, actual paper: 2409.11252.html
# Elaborazione del paper 2409.11252.html
# Paper elaborati:  487, actual paper: 2409.11263.html
# Elaborazione del paper 2409.11263.html
# Paper elaborati:  488, actual paper: 2409.11564.html
# Elaborazione del paper 2409.11564.html
# Paper elaborati:  489, actual paper: 2409.11677.html
# Elaborazione del paper 2409.11677.html
# Paper elaborati:  490, actual paper: 2409.12306.html
# Elaborazione del paper 2409.12306.html
# Paper elaborati:  491, actual paper: 2409.12388.html
# Elaborazione del paper 2409.12388.html
# Paper elaborati:  492, actual paper: 2409.12553.html
# Elaborazione del paper 2409.12553.html
# Paper elaborati:  493, actual paper: 2409.13268.html
# Elaborazione del paper 2409.13268.html
# Paper elaborati:  494, actual paper: 2409.13483.html
# Elaborazione del paper 2409.13483.html
# Paper elaborati:  495, actual paper: 2409.13557.html
# Elaborazione del paper 2409.13557.html
# Paper elaborati:  496, actual paper: 2409.13689.html
# Elaborazione del paper 2409.13689.html
# Paper elaborati:  497, actual paper: 2409.13726.html
# Elaborazione del paper 2409.13726.html
# Paper elaborati:  498, actual paper: 2409.13878.html
# Elaborazione del paper 2409.13878.html
